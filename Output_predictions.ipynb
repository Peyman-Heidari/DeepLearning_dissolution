# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tensorflow as tf
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn import preprocessing
from sklearn.metrics import r2_score
from statistics import mean
import usefulFuncs as uf
import pickle

# %matplotlib inline

# %%
with open('objs.pickle','rb') as f:  # Python 3: open(..., 'rb')
    X_train, newxtest, y_train, y_validation_test = pickle.load(f)

# %%
X_test, X_validation, y_test, y_validation = train_test_split(newxtest,\
                                                            y_validation_test, test_size=0.5, random_state=1)

y_train = y_train.tolist()
y_validation = y_validation.tolist()
y_test = y_test.tolist()

y_train = np.reshape(y_train, (len(y_train),1))
y_validation = np.reshape(y_validation, (len(y_validation),1))
y_test = np.reshape(y_test, (len(y_test),1))

# %%
with open('variables245.pickle','rb') as g:  # Python 3: open(..., 'rb')
    weights1, weights2, weights3, weights4, weights5, weights6, weights7, weights8, weights9, weights10, weights11, weights12,\
                    weights13, weights14, weights_out, biases1, biases2, biases3, biases4, biases5, biases6, biases7,\
                    biases8, biases9, biases10, biases11, biases12, biases13, biases14, biase_out, train_prediction,\
                    valid_prediction, test_prediction, train_r2, valid_r2, test_r2 = pickle.load(g)

# %%
test_prediction
# Out:
# 'w4'

# %%
y_test
# Out:
# array([[  1.15170000e-03],
#        [  1.44190000e-03],
#        [  1.46430000e-03],
#        [  1.39000000e-03],
#        [  1.57470000e-03],
#        [  1.56340000e-03],
#        [  2.17730000e-03],
#        [  1.52910000e-03],
#        [  1.47840000e-03],
#        [  1.38190000e-03],
#        [  2.20400000e-03],
#        [  1.54120000e-03],
#        [  1.56810000e-03],
#        [  7.91000000e-04],
#        [  7.39300000e-04],
#        [  1.54610000e-03],
#        [  2.21690000e-03],
#        [  2.00130000e-03],
#        [  1.55360000e-03],
#        [  1.57600000e-03],
#        [  1.57810000e-03],
#        [  1.52200000e-03],
#        [  1.73480000e-03],
#        [  2.19170000e-03],
#        [  1.42270000e-03],
#        [  1.51370000e-03],
#        [  1.74490000e-03],
#        [  1.83770000e-03],
#        [  3.52500000e-04],
#        [  1.53520000e-03],
#        [  1.65580000e-03],
#        [  1.56910000e-03],
#        [  9.84100000e-04],
#        [  1.13950000e-03],
# ...
